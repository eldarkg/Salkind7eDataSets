# %%
import pyreadstat
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import seaborn as sns

# %%
df,_ = pyreadstat.read_sav('/home/eldar/Work/Salkind7eDataSets/datasets/Chapter 5 Data Set 2.sav')

# %%
pearsonr(df['Number_Correct'], df['Attitude'])
# Out:
# PearsonRResult(statistic=0.5960947613894625, pvalue=0.06895208300005355)

# %%
sns.set_style('whitegrid')
sns.scatterplot(x=df['Number_Correct'], y=df['Attitude'])
# Out:
# <Axes: xlabel='Number_Correct', ylabel='Attitude'>
