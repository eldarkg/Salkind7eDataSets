# %%
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df,_ = pyreadstat.read_sav('~/Work/Learning/Salkind7eDataSets/datasets/Chapter 4 Data Set 1.sav')

# %%
sns.set_style('whitegrid')
sns.histplot(df, binwidth=5, binrange=(0, 59))
plt.show()
