# %%
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df,_ = pyreadstat.read_sav('~/Work/Learning/Salkind7eDataSets/datasets/Chapter 4 Data Set 2.sav')

# %%
sns.set_style('whitegrid')
sns.barplot(df, estimator='sum', errorbar=None)
plt.show()
