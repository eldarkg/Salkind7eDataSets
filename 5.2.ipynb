# %%
import pyreadstat
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import seaborn as sns

# %%
df,_ = pyreadstat.read_sav('/home/eldar/Work/Salkind7eDataSets/datasets/Chapter 5 Data Set 3.sav')

# %%
r = pearsonr(df['Speed'], df['Strength']).statistic
print(r)
r_d = r ** 2
print(r_d)
# Out:
# -0.41780985115926794
# 0.17456507172572963

# %%
sns.set_style('whitegrid')
sns.scatterplot(x=df['Speed'], y=df['Strength'])
# Out:
# <Axes: xlabel='Speed', ylabel='Strength'>
