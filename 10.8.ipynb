# %%
from statsmodels.stats.descriptivestats import describe
from statsmodels.stats.weightstats import ztest

# %%
data = (34518, 29540, 34889, 26764, 31429, 29962, 31084, 30506, 28546, 29560, 29304, 25852)
value = 31456

# %%
describe(data)
# Out:
#                              0
# nobs                 12.000000
# missing               0.000000
# mean              30162.833333
# std_err             769.456605
# upper_ci          31670.940567
# lower_ci          28654.726100
# std                2665.475869
# iqr                2055.750000
# iqr_normal         1523.929755
# mad                1935.305556
# mad_normal         2425.545813
# coef_var              0.088370
# range              9037.000000
# max               34889.000000
# min               25852.000000
# skew                  0.332540
# kurtosis              2.649296
# jarque_bera           0.282662
# jarque_bera_pval      0.868202
# mode              25852.000000
# mode_freq             0.083333
# median            29761.000000
# 1%                25952.320000
# 5%                26353.600000
# 10%               26942.200000
# 25%               29114.500000
# 50%               29761.000000
# 75%               31170.250000
# 90%               34209.100000
# 95%               34684.950000
# 99%               34848.190000

# %%
ztest(data, value=value)
# Out:
# (-1.6806232580916634, 0.09283611527618582)
