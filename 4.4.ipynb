# %%
import pyreadstat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df,_ = pyreadstat.read_sav('~/Work/Learning/Salkind7eDataSets/datasets/Chapter 4 Data Set 3.sav')

# %%
sns.set_style('whitegrid')
vc = df.value_counts()
plt.pie(vc, labels=vc.index)
plt.show()
